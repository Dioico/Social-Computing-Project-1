# %% [markdown]
# # PROGETTO 1 SOCIAL COMPUTING
#
# ## 1. DOWNLOAD FOLLOWER E FOLLOWING
# Scaricate utenti followers (api.followers) e utenti following (api.friends) di
# questi cinque account (i dati numerici potrebbero subire minime variazioni):
# 	- @mizzaro - 156 Follower - 331 Following
# 	- @damiano10 - 785 Follower - 836 Following
# 	- @Miccighel_ - 331 Follower - 211 Following
# 	- @eglu81 - 540 Follower - 621 Following
# 	- @KevinRoitero - 103 Follower - 256 Following

# %%
from config import *
from utility import *
import os
import json
import pprint
import tweepy

pp = pprint.PrettyPrinter()

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
if(api.verify_credentials):
    print('Authentication completed succesfully!')

#Serializzazione JSON
data_folder = "data"

def serialize_json(folder, filename, data):
    if not os.path.exists(folder):
        os.makedirs(folder, exist_ok=True)
    with open(f"{folder}/{filename}", "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    print(f"Data serialized to path: {folder}/{filename}")

def read_json(path):
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as file:
            data = json.load(file)
        print(f"Data read from path: {path}")
        return data
    else:
        print(f"No data found at path: {path}")
        return {}

def getFollowers(account, path):
    followers_of_account = []

    for item in tweepy.Cursor(
            api.followers,
            screen_name=account,
            skip_status=True,
            include_user_entities=False
    ).items(500):

        json_data = item._json

        found_follower = {}
        found_follower["id"] = json_data["id"]
        found_follower["name"] = json_data["name"]
        found_follower["screen_name"] = json_data["screen_name"]
        found_follower["location"] = json_data["location"]
        if found_follower not in followers_of_account:
            followers_of_account.append(found_follower)
        print(f"Processing Follower {len(followers_of_account)} of account: {account}")

    serialize_json(data_folder, path, followers_of_account)

def getFollowing(account, path):
    followings_of_account = []

    for item in tweepy.Cursor(
            api.friends,
            screen_name=account,
            skip_status=True,
            include_user_entities=False
    ).items():

        json_data = item._json

        found_following = {}
        found_following["id"] = json_data["id"]
        found_following["name"] = json_data["name"]
        found_following["screen_name"] = json_data["screen_name"]
        found_following["location"] = json_data["location"]
        if found_following not in followings_of_account:
            followings_of_account.append(found_following)
        print(f"Processing Following {len(followings_of_account)} of account: {account}")

    serialize_json(data_folder, path, followings_of_account)
# Out:
# Authentication completed succesfully!

# %%
getFollowers("mizzaro", "mizzaroFollowers.json")

# %%
getFollowers("damiano10", "damiano10Followers.json")
# Out:
# Processing Follower 1 of account: damiano10
# Processing Follower 2 of account: damiano10
# Processing Follower 3 of account: damiano10
# Processing Follower 4 of account: damiano10
# Processing Follower 5 of account: damiano10
# Processing Follower 6 of account: damiano10
# Processing Follower 7 of account: damiano10
# Processing Follower 8 of account: damiano10
# Processing Follower 9 of account: damiano10
# Processing Follower 10 of account: damiano10
# Processing Follower 11 of account: damiano10
# Processing Follower 12 of account: damiano10
# Processing Follower 13 of account: damiano10
# Processing Follower 14 of account: damiano10
# Processing Follower 15 of account: damiano10
# Processing Follower 16 of account: damiano10
# Processing Follower 17 of account: damiano10
# Processing Follower 18 of account: damiano10
# Processing Follower 19 of account: damiano10
# Processing Follower 20 of account: damiano10
# Processing Follower 21 of account: damiano10
# Processing Follower 22 of account: damiano10
# Processing Follower 23 of account: damiano10
# Processing Follower 24 of account: damiano10
# Processing Follower 25 of account: damiano10
# Processing Follower 26 of account: damiano10
# Processing Follower 27 of account: damiano10
# Processing Follower 28 of account: damiano10
# Processing Follower 29 of account: damiano10
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [WinError 10054] Connessione in corso interrotta forzatamente dall'host remoto
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     402             if read is False or not self._is_method_retryable(method):
# --> 403                 raise six.reraise(type(error), error, _stacktrace)
#     404             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, "Connessione in corso interrotta forzatamente dall'host remoto", None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, "Connessione in corso interrotta forzatamente dall'host remoto", None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-26-440879f785f4> in <module>
# ----> 1 getFollowers("damiano10", "damiano10Followers.json")
#       2
#
# <ipython-input-25-0fc1ec7c7065> in getFollowers(account, path)
#      37     followers_of_account = []
#      38
# ---> 39     for item in tweepy.Cursor(
#      40             api.followers,
#      41             screen_name=account,
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     217         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     218             # Reached end of current page, get the next page...
# --> 219             self.current_page = self.page_iterator.next()
#     220             while len(self.current_page) == 0:
#     221                 self.current_page = self.page_iterator.next()
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#      71         if self.next_cursor == 0 or (self.limit and self.num_tweets == self.limit):
#      72             raise StopIteration
# ---> 73         data, cursors = self.method(cursor=self.next_cursor,
#      74                                     *self.args,
#      75                                     **self.kwargs)
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     250                 return method
#     251             else:
# --> 252                 return method.execute()
#     253         finally:
#     254             method.session.close()
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~\anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     700                 value = tp()
#     701             if value.__traceback__ is not tb:
# --> 702                 raise value.with_traceback(tb)
#     703             raise value
#     704         finally:
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     182                 # Execute request
#     183                 try:
# --> 184                     resp = self.session.request(self.method,
#     185                                                 full_url,
#     186                                                 data=self.post_data,
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# TweepError: Failed to send request: ('Connection aborted.', ConnectionResetError(10054, "Connessione in corso interrotta forzatamente dall'host remoto", None, 10054, None))

# %%
getFollowers("Miccighel_", "Miccighel_Followers.json")

# %%
getFollowers("eglu81", "eglu81Followers.json")

# %%
getFollowers("KevinRoitero", "KevinRoiteroFollowers.json")

# %%
getFollowing("mizzaro", "mizzaroFollowers.json")

# %%
getFollowing("damiano10", "damiano10Followers.json")

# %%
getFollowing("Miccighel_", "Miccighel_Followers.json")

# %%
getFollowing("eglu81", "eglu81Followers.json")

# %%
getFollowing("KevinRoitero", "KevinRoiteroFollowings.json")

# %% [markdown]
# ## 2. CINQUE UTENTI RANDOM FOLLOWERS
# Scegliete 5 utenti followers a caso tra quelli di ciascuno dei cinque account e
# scaricate ulteriori 10 utenti followers (followers dei followers)

# %%
import random

def random(read_path, save_path):
    data_account = read_json(read_path)
    random_account = []
    number_of_account = len(data_account)
    print(f"Followers: {number_of_account}")
    for x in range(5):
        rand = random.randint(0,number_of_account-1)
        #pp.pprint(rand)
        pp.pprint(data_account[rand])
        if data_account[rand] not in random_account:
            random_account.append(data_account[rand])
        else:
            x = x-1

    serialize_json(data_folder, save_path, random_account)


random("data/KevinRoiteroFollowers.json", "KevinRoiteroRandomFollowers.json")

# %%
while True:
        try:
            getFollowers("Miccighel_", "Miccighel_Followers.json")
            break
        except tweepy.TweepError as e:
            print(e.reason)
            sleep(60*backoff_counter)
            backoff_counter += 1
            continue
# Out:
# Processing Follower 1 of account: Miccighel_
# Processing Follower 2 of account: Miccighel_
# Processing Follower 3 of account: Miccighel_
# Processing Follower 4 of account: Miccighel_
# Processing Follower 5 of account: Miccighel_
# Processing Follower 6 of account: Miccighel_
# Processing Follower 7 of account: Miccighel_
# Processing Follower 8 of account: Miccighel_
# Processing Follower 9 of account: Miccighel_
# Processing Follower 10 of account: Miccighel_
# Processing Follower 11 of account: Miccighel_
# Processing Follower 12 of account: Miccighel_
# Processing Follower 13 of account: Miccighel_
# Processing Follower 14 of account: Miccighel_
# Processing Follower 15 of account: Miccighel_
# Processing Follower 16 of account: Miccighel_
# Processing Follower 17 of account: Miccighel_
# Processing Follower 18 of account: Miccighel_
# Processing Follower 19 of account: Miccighel_
# Processing Follower 20 of account: Miccighel_
# Processing Follower 21 of account: Miccighel_
# Processing Follower 22 of account: Miccighel_
# Processing Follower 23 of account: Miccighel_
# Processing Follower 24 of account: Miccighel_
# Processing Follower 25 of account: Miccighel_
# Processing Follower 26 of account: Miccighel_
# Processing Follower 27 of account: Miccighel_
# Processing Follower 28 of account: Miccighel_
# Processing Follower 29 of account: Miccighel_
# Processing Follower 30 of account: Miccighel_
# Processing Follower 31 of account: Miccighel_
# Processing Follower 32 of account: Miccighel_
# Processing Follower 33 of account: Miccighel_
# Processing Follower 34 of account: Miccighel_
# Processing Follower 35 of account: Miccighel_
# Processing Follower 36 of account: Miccighel_
# Processing Follower 37 of account: Miccighel_
# Processing Follower 38 of account: Miccighel_
# Processing Follower 39 of account: Miccighel_
# Processing Follower 40 of account: Miccighel_
# Processing Follower 41 of account: Miccighel_
# Processing Follower 42 of account: Miccighel_
# Processing Follower 43 of account: Miccighel_
# Processing Follower 44 of account: Miccighel_
# Processing Follower 45 of account: Miccighel_
# Processing Follower 46 of account: Miccighel_
# Processing Follower 47 of account: Miccighel_
# Processing Follower 48 of account: Miccighel_
# Processing Follower 49 of account: Miccighel_
# Processing Follower 50 of account: Miccighel_
# Processing Follower 51 of account: Miccighel_
# Processing Follower 52 of account: Miccighel_
# Processing Follower 53 of account: Miccighel_
# Processing Follower 54 of account: Miccighel_
# Processing Follower 55 of account: Miccighel_
# Processing Follower 56 of account: Miccighel_
# Processing Follower 57 of account: Miccighel_
# Processing Follower 58 of account: Miccighel_
# Processing Follower 59 of account: Miccighel_
# Processing Follower 60 of account: Miccighel_
# Processing Follower 61 of account: Miccighel_
# Processing Follower 62 of account: Miccighel_
# Processing Follower 63 of account: Miccighel_
# Processing Follower 64 of account: Miccighel_
# Processing Follower 65 of account: Miccighel_
# Processing Follower 66 of account: Miccighel_
# Processing Follower 67 of account: Miccighel_
# Processing Follower 68 of account: Miccighel_
# Processing Follower 69 of account: Miccighel_
# Processing Follower 70 of account: Miccighel_
# Processing Follower 71 of account: Miccighel_
# Processing Follower 72 of account: Miccighel_
# Processing Follower 73 of account: Miccighel_
# Processing Follower 74 of account: Miccighel_
# Processing Follower 75 of account: Miccighel_
# Processing Follower 76 of account: Miccighel_
# Processing Follower 77 of account: Miccighel_
# Processing Follower 78 of account: Miccighel_
# Processing Follower 79 of account: Miccighel_
# Processing Follower 80 of account: Miccighel_
# Processing Follower 81 of account: Miccighel_
# Processing Follower 82 of account: Miccighel_
# Processing Follower 83 of account: Miccighel_
# Processing Follower 84 of account: Miccighel_
# Processing Follower 85 of account: Miccighel_
# Processing Follower 86 of account: Miccighel_
# Processing Follower 87 of account: Miccighel_
# Processing Follower 88 of account: Miccighel_
# Processing Follower 89 of account: Miccighel_
# Processing Follower 90 of account: Miccighel_
# Processing Follower 91 of account: Miccighel_
# Processing Follower 92 of account: Miccighel_
# Processing Follower 93 of account: Miccighel_
# Processing Follower 94 of account: Miccighel_
# Processing Follower 95 of account: Miccighel_
# Processing Follower 96 of account: Miccighel_
# Processing Follower 97 of account: Miccighel_
# Processing Follower 98 of account: Miccighel_
# Processing Follower 99 of account: Miccighel_
# Processing Follower 100 of account: Miccighel_
# Processing Follower 101 of account: Miccighel_
# Processing Follower 102 of account: Miccighel_
# Processing Follower 103 of account: Miccighel_
# Processing Follower 104 of account: Miccighel_
# Processing Follower 105 of account: Miccighel_
# Processing Follower 106 of account: Miccighel_
# Processing Follower 107 of account: Miccighel_
# Processing Follower 108 of account: Miccighel_
# Processing Follower 109 of account: Miccighel_
# Processing Follower 110 of account: Miccighel_
# Processing Follower 111 of account: Miccighel_
# Processing Follower 112 of account: Miccighel_
# Processing Follower 113 of account: Miccighel_
# Processing Follower 114 of account: Miccighel_
# Processing Follower 115 of account: Miccighel_
# Processing Follower 116 of account: Miccighel_
# Processing Follower 117 of account: Miccighel_
# Processing Follower 118 of account: Miccighel_
# Processing Follower 119 of account: Miccighel_
# Processing Follower 120 of account: Miccighel_
# Processing Follower 121 of account: Miccighel_
# Processing Follower 122 of account: Miccighel_
# Processing Follower 123 of account: Miccighel_
# Processing Follower 124 of account: Miccighel_
# Processing Follower 125 of account: Miccighel_
# Processing Follower 126 of account: Miccighel_
# Processing Follower 127 of account: Miccighel_
# Processing Follower 128 of account: Miccighel_
# Processing Follower 129 of account: Miccighel_
# Processing Follower 130 of account: Miccighel_
# Processing Follower 131 of account: Miccighel_
# Processing Follower 132 of account: Miccighel_
# Processing Follower 133 of account: Miccighel_
# Processing Follower 134 of account: Miccighel_
# Processing Follower 135 of account: Miccighel_
# Processing Follower 136 of account: Miccighel_
# Processing Follower 137 of account: Miccighel_
# Processing Follower 138 of account: Miccighel_
# Processing Follower 139 of account: Miccighel_
# Processing Follower 140 of account: Miccighel_
# Processing Follower 141 of account: Miccighel_
# Processing Follower 142 of account: Miccighel_
# Processing Follower 143 of account: Miccighel_
# Processing Follower 144 of account: Miccighel_
# Processing Follower 145 of account: Miccighel_
# Processing Follower 146 of account: Miccighel_
# Processing Follower 147 of account: Miccighel_
# Processing Follower 148 of account: Miccighel_
# Processing Follower 149 of account: Miccighel_
# Processing Follower 150 of account: Miccighel_
# Processing Follower 151 of account: Miccighel_
# Processing Follower 152 of account: Miccighel_
# Processing Follower 153 of account: Miccighel_
# Processing Follower 154 of account: Miccighel_
# Processing Follower 155 of account: Miccighel_
# Processing Follower 156 of account: Miccighel_
# Processing Follower 157 of account: Miccighel_
# Processing Follower 158 of account: Miccighel_
# Processing Follower 159 of account: Miccighel_
# Processing Follower 160 of account: Miccighel_
# Processing Follower 161 of account: Miccighel_
# Processing Follower 162 of account: Miccighel_
# Processing Follower 163 of account: Miccighel_
# Processing Follower 164 of account: Miccighel_
# Processing Follower 165 of account: Miccighel_
# Processing Follower 166 of account: Miccighel_
# Processing Follower 167 of account: Miccighel_
# Processing Follower 168 of account: Miccighel_
# Processing Follower 169 of account: Miccighel_
# Processing Follower 170 of account: Miccighel_
# Processing Follower 171 of account: Miccighel_
# Processing Follower 172 of account: Miccighel_
# Processing Follower 173 of account: Miccighel_
# Processing Follower 174 of account: Miccighel_
# Processing Follower 175 of account: Miccighel_
# Processing Follower 176 of account: Miccighel_
# Processing Follower 177 of account: Miccighel_
# Processing Follower 178 of account: Miccighel_
# Processing Follower 179 of account: Miccighel_
# Processing Follower 180 of account: Miccighel_
# Processing Follower 181 of account: Miccighel_
# Processing Follower 182 of account: Miccighel_
# Processing Follower 183 of account: Miccighel_
# Processing Follower 184 of account: Miccighel_
# Processing Follower 185 of account: Miccighel_
# Processing Follower 186 of account: Miccighel_
# Processing Follower 187 of account: Miccighel_
# Processing Follower 188 of account: Miccighel_
# Processing Follower 189 of account: Miccighel_
# Processing Follower 190 of account: Miccighel_
# Processing Follower 191 of account: Miccighel_
# Processing Follower 192 of account: Miccighel_
# Processing Follower 193 of account: Miccighel_
# Processing Follower 194 of account: Miccighel_
# Processing Follower 195 of account: Miccighel_
# Processing Follower 196 of account: Miccighel_
# Processing Follower 197 of account: Miccighel_
# Processing Follower 198 of account: Miccighel_
# Processing Follower 199 of account: Miccighel_
# Processing Follower 200 of account: Miccighel_
# Processing Follower 201 of account: Miccighel_
# Processing Follower 202 of account: Miccighel_
# Processing Follower 203 of account: Miccighel_
# Processing Follower 204 of account: Miccighel_
# Processing Follower 205 of account: Miccighel_
# Processing Follower 206 of account: Miccighel_
# Processing Follower 207 of account: Miccighel_
# Processing Follower 208 of account: Miccighel_
# Processing Follower 209 of account: Miccighel_
# Processing Follower 210 of account: Miccighel_
# Processing Follower 211 of account: Miccighel_
# Processing Follower 212 of account: Miccighel_
# Processing Follower 213 of account: Miccighel_
# Processing Follower 214 of account: Miccighel_
# Processing Follower 215 of account: Miccighel_
# Processing Follower 216 of account: Miccighel_
# Processing Follower 217 of account: Miccighel_
# Processing Follower 218 of account: Miccighel_
# Processing Follower 219 of account: Miccighel_
# Processing Follower 220 of account: Miccighel_
# Processing Follower 221 of account: Miccighel_
# Processing Follower 222 of account: Miccighel_
# Processing Follower 223 of account: Miccighel_
# Processing Follower 224 of account: Miccighel_
# Processing Follower 225 of account: Miccighel_
# Processing Follower 226 of account: Miccighel_
# Processing Follower 227 of account: Miccighel_
# Processing Follower 228 of account: Miccighel_
# Processing Follower 229 of account: Miccighel_
# Processing Follower 230 of account: Miccighel_
# Processing Follower 231 of account: Miccighel_
# Processing Follower 232 of account: Miccighel_
# Processing Follower 233 of account: Miccighel_
# Processing Follower 234 of account: Miccighel_
# Processing Follower 235 of account: Miccighel_
# Processing Follower 236 of account: Miccighel_
# Processing Follower 237 of account: Miccighel_
# Processing Follower 238 of account: Miccighel_
# Processing Follower 239 of account: Miccighel_
# Processing Follower 240 of account: Miccighel_
# Processing Follower 241 of account: Miccighel_
# Processing Follower 242 of account: Miccighel_
# Processing Follower 243 of account: Miccighel_
# Processing Follower 244 of account: Miccighel_
# Processing Follower 245 of account: Miccighel_
# Processing Follower 246 of account: Miccighel_
# Processing Follower 247 of account: Miccighel_
# Processing Follower 248 of account: Miccighel_
# Processing Follower 249 of account: Miccighel_
# Processing Follower 250 of account: Miccighel_
# Processing Follower 251 of account: Miccighel_
# Processing Follower 252 of account: Miccighel_
# Processing Follower 253 of account: Miccighel_
# Processing Follower 254 of account: Miccighel_
# Processing Follower 255 of account: Miccighel_
# Processing Follower 256 of account: Miccighel_
# Processing Follower 257 of account: Miccighel_
# Processing Follower 258 of account: Miccighel_
# Processing Follower 259 of account: Miccighel_
# Processing Follower 260 of account: Miccighel_
# Processing Follower 261 of account: Miccighel_
# Processing Follower 262 of account: Miccighel_
# Processing Follower 263 of account: Miccighel_
# Processing Follower 264 of account: Miccighel_
# Processing Follower 265 of account: Miccighel_
# Processing Follower 266 of account: Miccighel_
# Processing Follower 267 of account: Miccighel_
# Processing Follower 268 of account: Miccighel_
# Processing Follower 269 of account: Miccighel_
# Processing Follower 270 of account: Miccighel_
# Processing Follower 271 of account: Miccighel_
# Processing Follower 272 of account: Miccighel_
# Processing Follower 273 of account: Miccighel_
# Processing Follower 274 of account: Miccighel_
# Processing Follower 275 of account: Miccighel_
# Processing Follower 276 of account: Miccighel_
# Processing Follower 277 of account: Miccighel_
# Processing Follower 278 of account: Miccighel_
# Processing Follower 279 of account: Miccighel_
# Processing Follower 280 of account: Miccighel_
# Processing Follower 281 of account: Miccighel_
# Processing Follower 282 of account: Miccighel_
# Processing Follower 283 of account: Miccighel_
# Processing Follower 284 of account: Miccighel_
# Processing Follower 285 of account: Miccighel_
# Processing Follower 286 of account: Miccighel_
# Processing Follower 287 of account: Miccighel_
# Processing Follower 288 of account: Miccighel_
# Processing Follower 289 of account: Miccighel_
# Processing Follower 290 of account: Miccighel_
# Processing Follower 291 of account: Miccighel_
# Processing Follower 292 of account: Miccighel_
# Processing Follower 293 of account: Miccighel_
# Processing Follower 294 of account: Miccighel_
# Processing Follower 295 of account: Miccighel_
# Processing Follower 296 of account: Miccighel_
# Processing Follower 297 of account: Miccighel_
# Processing Follower 298 of account: Miccighel_
# Processing Follower 299 of account: Miccighel_
# Processing Follower 300 of account: Miccighel_
# Rate limit reached. Sleeping for: 899

# %% [markdown]
# ## 3. CINQUE UTENTI RANDOM FOLLOWING
# Scegliete 5 utenti following a caso tra quelli di ciascuno dei cinque account e
# scaricate ulteriori 10 utenti following (following dei following)

# %% [markdown]
# ## 4. DETTAGLI PROFILI
# Scaricare i dettagli del profilo di tutti gli utenti recuperati

# %% [markdown]
# ## 5. COSTRUIRE RETE SOCIALE
# Costruite la rete sociale (grafo):
# 	- Inserite l’id di ciascun utente come identificatore del nodo
# 	- Ogni arco rappresenta una relazione follows tra due utenti
# 	- Inserite i dettagli del profilo di ciascun utente come attributi del nodo
# 	- Inserite i membri del vostro gruppo come attributi del grafo
# 	- Per ogni nodo, aggiungete un attributo con il numero di follower individuati
# ## 6.
# Producete una visualizzazione interattiva del grafo usando pyvis
# ## 7.
# Verificate se il grafo:
# 	- è connesso (is_connected)
# 	- è bipartito (is_bipartite)
# ## 8.
# Misurate le seguenti distanze sul grafo:
# 	- Centro (center)
# 	- Diametro (diameter)
# 	- Raggio (radius)
# ## 9.
# Calcolate le seguenti misure di centralità sul grafo:
# 	- Betweenness centrality (betweenness_centrality)
# 	- Closeness centrality (closeness_centrality)
# 	- Degree centrality (degree_centrality)
# 	- In-degree centrality (in_degree_centrality)
# 	- Out-degree centrality (out_degree_centrality)
# 	- Page Rank (pagerank)
# 	- HITS (hits)
# ## 10.
# Generate il sottografo indotto dal nodo damiano10 (ego_graph) e calcolate:
# 	- Cricca massima (max_clique)
# 	- Dimensione della cricca massima (large_clique_size)
# ## 11.
# Calcolate la copertura minima degli archi (min_edge_cover) del grafo
# ## 12.
# Calcolate i seguenti coefficienti per stimare la “small-world-ness” del grafo:
# 	- Coefficiente omega (omega)
# 	- Coefficiente sigma (sigma)
# ## 13.
# Calcolare la correlazione di Pearson Rho e di Kendall Tau fra le misure di centralità;
# riportare il risultato in due tabelle
